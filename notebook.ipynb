# %%
from src.scraping_api import extraer_comentarios_api
extraer_comentarios_api(channel_ids=[
  "UCmh7afBz-uWwOSSNTqUBAhg",
  "UCn4sPeUomNGIr26bElVdDYg"

],
videos_por_dia=20, dias_atras=30, max_videos_total= 500)
# Out:
#     ╔════════════════════════════════════════════════════════════╗
#     ║     EXTRACTOR DE COMENTARIOS - YOUTUBE API v3              ║
#     ║                                                            ║
#     ║  📊 Configuración:                                         ║
#     ║  • 50 comentarios por video                           ║
#     ║  • 20 videos por día                                  ║
#     ║  • 30 días hacia atrás                                 ║
#     ║  • Max 500 videos del canal                        ║
#     ║                                                            ║
#     ║  ⚠️ LÍMITES DE API:                                        ║
#     ║  • 10,000 unidades/día (cuota gratuita)                    ║
#     ║  • ~200-300 videos con comentarios por día                 ║
#     ╚════════════════════════════════════════════════════════════╝
#
# ✅ Cliente de YouTube API inicializado correctamente
#
# ...
# 🎯 CANAL 1/2: UCmh7afBz-uWwOSSNTqUBAhg
# ...
#
# ✅ Canal: Forbes
# ...

# %%
'''
Genero un archivo de los usuarios que comentaron en algun canal
'''
from src.scraping_api import usuarios_canal
usuarios_canal()

# %%
'''
Construyo la red de usuarios
'''
from src.construir_red_usuarios import construir_red_global_usuarios
G,df=construir_red_global_usuarios()
# Out:
# Archivo 'grafo_para_gephi.gexf' generado exitosamente
# Nodos (videos): 3215
# Aristas (conexiones): 81233
