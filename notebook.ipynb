# %%
from src.youtube_scraper_final import extraer_comentarios
extraer_comentarios()
# Out:
# ...
# 🎯 Procesando canal: UCsCE4IMMFuwPYbwDqaz7udQ
# ...
#
# 🔄 Actualizando 1 videos existentes para The Washington Times...
#
# 🔍 Obteniendo videos recientes para The Washington Times...
#    Configuración: 10 videos/día × 15 días
# 📅 Buscando videos desde 2026-01-16 hasta 2026-01-31 (15 días)...

# %%
import yt_dlp
print(yt_dlp.version.__version__)
# Out:
# 2026.01.29

# %%
# !pip install -U yt-dlp

# %%
import importlib
import yt_dlp

importlib.reload(yt_dlp)
print(yt_dlp.version.__version__)
# Out:
# 2026.01.29
